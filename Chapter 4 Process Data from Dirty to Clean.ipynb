# %% [markdown]
# ## Data integrity
# this is one of the cruisial, and important  things to look at in data. <br>
#
# data integrity simply means maintaining data in all aspects until the work done. <br>
#
# to explain data integrity, consider your working for a international company as an analyst. you have given several countries sales points. here, each country actually maintains its own date format, like 10/12/2020 this date can be 10th of december in US and 12th of october in europe. without understanding the date formats if you proceed with analysis it results in total error.
# <br>
# good analysis depends on the data intigrity.
# <br>
# some more scenarios may be<br>
# Data replication compromising data integrity: this might happen when copying the data with less memory availability. <br>
# Data transfer compromising data integrity: this happens when, transferring data to another format file, like excel to drive or any other presenting softwares. to explain, the headers in excel maybe considered as data points in tablue. (just example) <br>
# Data manipulation compromising data integrity: deleting, altering etc... needed to be done carefully.
#
# <br>
#
# #### some data constraints
# ##### Data type	->
# Values must be of a certain type: date, number, percentage, Boolean, etc.	<br>If the data type is a date, a single number like 30 would fail the constraint and be invalid
# ##### Data range->
# Values must fall between predefined maximum and minimum values	<br>If the data range is 10-20, a value of 30 would fail the constraint and be invalid
# ##### Mandatory	->
# Values can’t be left blank or empty	<br>If age is mandatory, that value must be filled in
# ##### Unique ->
# Values can’t have a duplicate<br>	Two people can’t have the same mobile phone number within the same service area
# ##### Regular expression (regex) patterns	->
# Values must match a prescribed pattern<br>	A phone number must match ###-###-#### (no other characters allowed)
#
# ##### Cross-field validation	->
# Certain conditions for multiple fields must be satisfied<br>	Values are percentages and values from multiple fields must add up to 100%
# ##### Primary-key	->
# (Databases only) value must be unique per column	<br>A database table can’t have two rows with the same primary key value. A primary key is an identifier in a database that references a column in which each value is unique. More information about primary and foreign keys is provided later in the program.
# ##### Set-membership	->
# (Databases only) values for a column must come from a set of discrete values <br>	Value for a column must be set to Yes, No, or Not Applicable
# ##### Foreign-key	->
# (Databases only) values for a column must be unique values coming from a column in another table	<br>In a U.S. taxpayer database, the State column must be a valid state or territory with the set of acceptable values defined in a separate States table
# ##### Accuracy->
# The degree to which the data conforms to the actual entity being measured or described	<br>If values for zip codes are validated by street location, the accuracy of the data goes up.
# ##### Completeness->
# The degree to which the data contains all desired components or measures	<br>If data for personal profiles required hair and eye color, and both are collected, the data is complete.
# ##### Consistency->
# The degree to which the data is repeatable from different points of entry or collection	<br>If a customer has the same address in the sales and repair databases, the data is consistent.

# %% [markdown]
# ##  types of Insufficient data
# Data from only one source <br>
# Data that keeps updating <br>
# outdated data <br>
# geographically limited data <br>
# ## ways to address insufficient data
# identify trends with available data <br>
# wait for more data if time allows <br>
# talk with stakeholders and adjust your objective <br>
# look for new data
#
# ## possible issues with data are
# ### error 1 -> no data
#     -> at this situation try to collect the possible amount of data to perform a preliminary analysis and than request for more time to collect the data. <br>
#     if you are surveying employees about what they think about a new performance and bonus plan, use a sample for a preliminary analysis. Then, ask for another 3 weeks to collect the data from all employees.
# <br>
#    ->if there is no time for collection of the data, use proxy data from another source.
#   <br>
#   for example, to know about a perticular city tourist atraction but you have no data, you can use another cities data which is similar in size and attributes
#
# ### error 2 -> too little data
# -> do the analysis with using proxy data with the actual data.
# <br> for example, If you are analyzing trends for owners of golden retrievers, make your dataset larger by including the data from owners of labradors.
# <br>
# ->Adjust your analysis to align with the data you already have. <br>
# If you are missing data for 18- to 24-year-olds, do the analysis but note the following limitation in your report: this conclusion applies to adults 25 years and older only.
# ### error 3 -> wrong data, including data with errors*
#  -> If you have the wrong data because requirements were misunderstood, communicate the requirements again.<br>
#  -> Identify errors in the data and, if possible, correct them at the source by looking for a pattern in the errors.<br>
#  -> If you can’t correct data errors yourself, you can ignore the
# wrong data and go ahead with the analysis if your sample size is still large enough and ignoring the data won’t cause systematic bias. <br>
#
#   for example, If your dataset was translated from a different language and some of the translations don’t make sense, ignore the data with bad translation and go ahead with the analysis of the other data.
#
#   ![de1.PNG](attachment:de1.PNG)

# %% [markdown]
# ![de3.PNG](attachment:de3.PNG)

# %% [markdown]
# ## Sample Size
#
#    sample size is the part of general population data, where it represents the population with same attributes and less data points.
#
#    <br>
#
#    generally, collecting and analysing on  the original population data is really time cosuming and cost effective, because collecting each and every data point is may or may not be possible at every time. because of that companies generates the sample data before the analyst starts analasys.
#
# #### general terminology in sampling
# ##### Population
# -> the entire group of data
# ##### Sample
# -> a subset of data
# ##### Margin of error
# ->Since a sample is used to represent a population, the sample’s results are expected to differ from what the result would have been if you had surveyed the entire population. This difference is called the margin of error. The smaller the margin of error, the closer the results of the sample are to what the result would have been if you had surveyed the entire population.
# ##### Confidence level
# -> How confident you are in the survey results. For example, a 95% confidence level means that if you were to run the same survey 100 times, you would get similar results 95 of those 100 times. Confidence level is targeted before you start your study because it will affect how big your margin of error is at the end of your study.
# ##### Confidence interval
# -> The range of possible values that the population’s result would be at the confidence level of the study. This range is the sample result +/- the margin of error.
# ##### Statistical significance
# -> The determination of whether your result could be due to random chance or not. The greater the significance, the less due to chance.
# <br>
# ###### When figuring out a sample size, here are things to keep in mind:
# <br>
# Don’t use a sample size less than 30. It has been statistically proven that 30 is the smallest sample size where an average<br> result of a sample starts to represent the average result of a population.<br>
# The confidence level most commonly used is 95%, but 90% can work in some cases.<br>
# Increase the sample size to meet specific needs of your project:<br>
# <br>
# For a higher confidence level, use a larger sample size<br>
# To decrease the margin of error, use a larger sample size<br>
# For greater statistical significance, use a larger sample size<br>
#
# an example of using proxy data will be, A new car model was just launched a few days ago and the auto dealership can’t wait until the end of the month for sales data to come in. They want sales projections now.so the analyst proxies the number of clicks to the car specifications on the dealership’s website as an estimate of potential sales at the dealership.
# <br>
# A brand new plant-based meat product was only recently stocked in grocery stores and the supplier needs to estimate the demand over the next four years. 	The analyst proxies the sales data for a turkey substitute made out of tofu that has been on the market for several years.

# %% [markdown]
# #### why no less than 30
# as per the central limit theorem of in the probability, the minimum of 30 samples are requered to draw the bell shaped curve. <br>
#  the theorem states that, the more the samples used, that accurate the bell curve is.
#  ## Statistical power
#
# Statistical power is the probability of getting meaningful results from a test. <br>
# Hypothesis testing is a way to see if a survey or experiment has meaningful results.<br>
#
# to understand the statistical power lets consider an example, consider working for a milk shake company as a data analyst. the company want to lauch a new kind of milk shake in several locations of their branches. before launching in all branches, it wants to know the effect of ads and increase in milk shake by collecting sample by some customers. if the sample size is 50 customers , it will be very low to calculate, why because may or may not be the overall 50 customers dont like milk shake at all. if we proceed with this their may be chance of bias and error in the result. to get better results lets increase the size of sample size. usually, the  greater the chance you'll have statistically significant results with your test. And that's statistical power.
# <br>
#
# in general it is considered as 0.8 or 80% as the best statistical significance.

# %% [markdown]
# ## how to get a sample population size.
#
# before, entering into it, needed to understand margin of error, confidence level. as we discussed above depending on these factors and total size of population we can calculate the sample size by using sample size calculators. ( which can be found in the internet).
#
# for example, you like to know how many students likes the chocolate out of a school. the overall population is 500 and youre confidence level is 95 and margin of error is 5.( it is not mandatory to be sum up 100 of those two, MOE can be any thing, those are independent values). to calculate the sample size.
# ![ssc.PNG](attachment:ssc.PNG)

# %% [markdown]
#  the sample size of 500 population with the respected confidence interval and MOE is 218. this means 218 members are enogh to know how many likes the chocolate in that school.
#
#  here, the confidence level, differs accordingly with the industry and situation. most of the organizations takes it as 90 to 95

# %% [markdown]
# ## Margin of Error
# Margin of error is the maximum amount that the sample results are expected to differ from those of the actual population.
# <br>
# for example, your doing a drug test on 500 people, which is your sample size of population 8000000, and the confidence level is  99% because it is drug test and you want to know the margin of error.<br>
# you can find the calculators in the online.
#
# ![mof.PNG](attachment:mof.PNG)

# %% [markdown]
# ## what is dirty data
#  a data that is not ready, it consist of some  of following errors. also, remember, no data is perfect.
#  -> dupicate
#  -> outdated
#  -> incorrect
#  -> inconsistent ( the data that uses different formats)
#
#  for example, cosider a sales data of week, there is one person bought only one item but data shows 2 times, because he try to buy it each time with different names or mail id. (generally this happens when page refresh or signal loss  in online markets). this leads to inconsitent data and results will change.

# %% [markdown]
# ## common data cleaning pitfalls
# ![pit1.PNG](attachment:pit1.PNG)

# %% [markdown]
# ![pit%202.PNG](attachment:pit%202.PNG)

# %% [markdown]
# ## Workflow automation
# there are some processes that can be automated, where some cant.
# #### Communicating with your team and stakeholders
# no, it cant be automated.<br>
# Communication is key to understanding the needs of your team and stakeholders as you complete the tasks you are working on. There is no replacement for person-to-person communications.
# #### Presenting your findings
# no <br>
# Presenting your data is a big part of your job as a data analyst. Making data accessible and understandable to stakeholders and creating data visualizations can’t be automated for the same reasons that communications can’t be automated.
# #### Preparing and cleaning data
# Partially <br>
# Some tasks in data preparation and cleaning can be automated by setting up specific processes, like using a programming script to automatically detect missing values.
# #### Data exploration
# Partially <br>
# Sometimes the best way to understand data is to see it. Luckily, there are plenty of tools available that can help automate the process of visualizing data. These tools can speed up the process of visualizing and understanding the data, but the exploration itself still needs to be done by a data analyst.
# #### Modeling the data
# Yes <br>
# Data modeling is a difficult process that involves lots of different factors; luckily there are tools that can completely automate the different stages.

# %% [markdown]
# ## Data mapping
# this is a process of matching fields from one to another
