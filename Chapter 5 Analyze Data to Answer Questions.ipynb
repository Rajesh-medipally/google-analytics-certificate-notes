# %% [markdown]
# ## Analysis
# The process used to make sense of data collected <br>
# The goal of analysis is to identify trends and relationships within the data so that you can accurately answer the question you're asking. <br>
# ## The 4 Phases of Analysis
# 1. Organize data -> it is like a registary where data is organized ( contact list in phone)
# 2. Format and adjust data -> filtering and sorting data
# 3. Get input from others -> the updates about working data
# 4. Transform the data -> identifying relationships, formats and calculating results on the base of data you have

# %% [markdown]
# ## Phase 1
# ## Organize data for analysis
#
# Most of the data you'll use in your analysis will be organized in tables. Tables help you organize similar kinds of data into categories and subject areas that you can focus on as you analyze.
# <br>
# organizing data means, ability to find what we wanted in a visual procedure.<br>
# most of the organizing part includes sorting and filtering the data.<br>
# Sorting is when you arrange data into a meaningful order to make it easier to understand, analyze, and visualize. <br>
# Filtering is showing only the data that meets a specific criteria while hiding the rest.<br>
#
# ## Phase 2
# #### Sorting in spreadsheet
# spreadsheet offers 2 types of sorting options.<br>
# -> Sorting sheet : which, where you select a cell and sort according to ascending or descending, and all the corresponding table rows will change automatically with respect to the<br> selected cell.<br>
# -> Sorting Range : this option is little different, in this option, you select some coulumns and sort asceding or desceding, but only the selected column will be sorted, the other columns will stay as it is, eventually if you have no purpose you will end up with wrong data.<br>
#
# most oftenly we use sort sheet function only, in rare special cases sort range.
# <br>
# below shows sorted using sort sheet option on film dates.
# <br>
# ![soshe.PNG](attachment:soshe.PNG)

# %% [markdown]
# the below one shows using sort range option on movies, observe the other columns, those didnt changed.
# ![sora.PNG](attachment:sora.PNG)

# %% [markdown]
# Spredsheet also have sorting funtion wich follows as
# <br>
# ###### =SORT(column range, on the base which column has to be sorted (in number), ascending =true)
# ![sorfun.PNG](attachment:sorfun.PNG)

# %% [markdown]
# ## sorting with sql
# ![seord.PNG](attachment:seord.PNG)

# %% [markdown]
# sorting with condition <br>
#
# the order by clause always comes in last in query
#
# ![consor.PNG](attachment:consor.PNG)

# %% [markdown]
# ## If condition in sql
# ##### IF(condition , do this if true, do this if false)
#
# to understand, considering an example public data from san box, GSOD of Global Surface Summary of the Day Weather Data . <br>
#
# <br>
# consider, The meteorologists who you’re working with have asked you to get the temperature, wind speed, and precipitation for stations La Guardia and JFK, for every day in 2020, in descending order by date, and ascending order by Station ID. Use the following query to request this information:

# %% [markdown]
# ![qr2.PNG](attachment:qr2.PNG)

# %% [markdown]
# this query looks fine and returns the result we wanted. <br>
# but in the schema it also mentioned that, they have handled null values by giving them as 9999.99 etc.. as below
# ![temp.PNG](attachment:temp.PNG)

# %% [markdown]
# ![wdsp.PNG](attachment:wdsp.PNG)

# %% [markdown]
# ![prcp.PNG](attachment:prcp.PNG)

# %% [markdown]
# so, even the above query works, because of there are hundres of reults we cant track them by each, to replace these values by NULL we are using IF function.

# %% [markdown]
# ![fqr.PNG](attachment:fqr.PNG)

# %% [markdown]
# ## Convert and Format
# after cleaning and processing the data converting the data format is the next step. it makes easy to understand the data.<br>
# some conversion samples are here,<br>
#
# ## Date format
#
# #### DATEVALUE(column) in excel
# this will convert the string into date type in excel. after in converts it saves in a serial number result, so needed to apply data format to see the actual date of it.
# <br>
# also it works only after from january 1 1900.
# ![datevalue%20excel.PNG](attachment:datevalue%20excel.PNG)

# %% [markdown]
# ##  Date format in google sheets
# For its internal database, Google Sheets stores all dates as integer numbers. Not sequences of a day, month, and year as we got used to seeing, but simple integers:<br>
# <br>
# <br>1 for December 31, 1899<br>
# 2 for January 1, 1900<br>
# 102 for November 4, 1900 (100 days after January 1, 1900)<br>
# and so on.<br>
# Unlike Excel that cannot store dates as negative numbers, in Google, for dates prior to December 31, 1899, the numbers will be negative:<br>
#
# -1 for December 29, 1899<br>
# -2 for December 28, 1899<br>
# -102 for September 19, 1899<br>
# etc.<br>
# Regardless of how Google Sheets formats dates for you to see in cells, spreadsheets always store them as integers. It's an automatic Google Sheets date format that helps to treat dates correctly.<br>
#
#
# changing the date format in google sheet is by clicking the option in the menu bar format.

# %% [markdown]
# #### REGEXREPLACE(column,replace this, by this)
# ![reg.PNG](attachment:reg.PNG)

# %% [markdown]
# ## Data validation
# this is an option in spreadsheets to handle the inputs of a perticular cell. specially it will be useful when working with team. this option provides several option like choose menu, check box also no input.
# ![dataval.PNG](attachment:dataval.PNG)

# %% [markdown]
# ## Conditional Formatting
# this is an another option in spreadsheet allow us to highlight some specific conditions. <br>
# for example, <br>1) if you wanted highlight the dates after todat with green,<br> 2) highlight done, doing, started with different colors.
#
# <br>
#
# ![con%20for.PNG](attachment:con%20for.PNG)

# %% [markdown]
# ## converting in SQL
# #### CAST function
# as we already used, cast funtion type castes the field from one data type to another. here are uses.
# ![cex.PNG](attachment:cex.PNG)

# %% [markdown]
# ![cstr.PNG](attachment:cstr.PNG)

# %% [markdown]
# ![cint.PNG](attachment:cint.PNG)

# %% [markdown]
# ![cdate.PNG](attachment:cdate.PNG)

# %% [markdown]
# the safe_cast returns the NULL instead of error in casting
# ![scex.PNG](attachment:scex.PNG)

# %% [markdown]
# #### some functions
# LEN to count the length =LEN(column) <br>
# LEFT to make substring from left side =LEFT(column, how many decimals)

# %% [markdown]
# ## String manipulation in sql
# concat function
# ![concattable.PNG](attachment:concattable.PNG)

# %% [markdown]
# <a href = "https://www.w3schools.com/sql/sql_ref_sqlserver.asp">there are some functions list in W3Schools</a>

# %% [markdown]
# basic important spreadsheet formulas. <br>
#
# 1. COUNTIF() for Conditional Counting
# <br>
# 2. TODAY() to update current date
# <br>
# 3. TEXT() to convert numbers into currency
# <br>
# 4. SPLIT() to divide data into multiple cells
# <br>
# 5. SEARCH() Function to Check Value in a String
# <br>
# 6. CONCATENATE() to Append Multiple Cells
# <br>
# 7. VLOOKUP() for Vertical Lookup
# <br>
# 8. IF() to Check Condition of a Logical Expression
# <br>
# 9. IFERROR() to Return Cell Error Value
# <br>
# 10. IMPORTRANGE() to Import a Range of Cells
# <br>
# 11. IMPORTFEED() to Import an RSS or ATOM Feed
# <br>
# 12. GROWTH() to predict the growing trend
# <br>
# 13. SUBSTITUTE() to replace existing text
# <br>
# 14. IMPORTXML() to import website data
# <br>
# 15. REGEXEXTRACT() to extract substrings
# <br>
# 16. TRANSPOSE() to transpose rows and columns
# <br>
# 17. QUERY() to Run a Google Visualization API Query
# <br>
# 18. ARRAYFORMULA() to Display of Values Returned
# <br>
# 19. SUMIF() to add numbers in a range cell
# <br>
# 20. SORT() to sort a range of cells<br>

# %% [markdown]
# ## Phase 3
#
# ## Aggregation
# collecting or gathering many separate pieces into whole. <br>
# So data aggregation is the process of gathering data from multiple sources in order to combine it into a single summarized collection.
# <br>
# here, it means simply combining data from multiple spreadsheets or databases to one result view.
# <br>
# #### VLOOKUP is used in spreadsheet
# about this function we already covered in prvious chapter, here we try to know the possible errors with it.<br>
# -> generally this function works to the right side of the funtion but cant work left side. it means, the resulting field must present right to the searching column. <br>
# -> the corresponding reference for the searching in vlookup will change when it dragged down, so it can be stopped by $ sign.        <br>
# -> some times peopl changes data, as per the needs in your works environment. if a search portion is present on certain data that has been changed, function will return error. to solve this always lock the spreadsheet after results.it done by protect sheet range in google sheets.<br>
# -> choosing true or false in this function results in veriety of ranges. generally, the function gets stopped when it founds nearly matching value without searching in the remaining sheet. that is why the analyst most often use false only.

# %% [markdown]
# When do you need to use VLOOKUP? <br>
#  Two common reasons to use VLOOKUP are:
# <br>
# ->Populating data in a spreadsheet
# <br>
# ->Merging data from one spreadsheet with data in another
# <br>
#
# when vlookup returns N/A it does not mean that problem with syntax. it means that the value is not found. to replace that, analysts use IFNA funtion
#
# ![ifna.PNG](attachment:ifna.PNG)

# %% [markdown]
# #### JOINS used in SQL
# JOIN is SQL clause that is used to combined rows from two or more tables based on related columns.
# <br>
# there are 4 common joins<br>
# inner<br>
# left<br>
# right<br>
# outer<br>
#
# ![joins.PNG](attachment:joins.PNG)

# %% [markdown]
# An inner JOIN is a function that returns records with matching values in both tables. <br>
# A LEFT JOIN is a function that will return all the records from the left table and only the matching records from the right table.<br>
# RIGHT JOIN does the opposite. It will return all records from the right table and only the matching records from the left. <br>
# OUTER join combines RIGHT and LEFT JOIN to return all matching records in both tables.
#
# ![jon%20syntax.PNG](attachment:jon%20syntax.PNG)

# %% [markdown]
# to understand the joins consider the tables below 'Orders' and 'Customers'
# ![tb1.PNG](attachment:tb1.PNG)

# %% [markdown]
# ![tb2.PNG](attachment:tb2.PNG)

# %% [markdown]
# in these 2 tables common column is customer id by using that, we can combine the tables.
#
# like,

# %% [markdown]
# ##### INNER JOIN OR JOIN
# <br>
#  <b>SELECT Orders.OrderId, Customers.CustomerName</b> <br>
#  <b>FROM Orders </b>        &nbsp;&nbsp;&nbsp;&nbsp;  -- the table here becomes left or main<br>
#  <b>INNER JOIN Customers</b>  &nbsp;&nbsp;&nbsp;&nbsp; -- this tells with witch table to join<br>
#  <b>ON Orders.CustomerID = Customers.CustomerID</b>    &nbsp;&nbsp;&nbsp;&nbsp;       -- this specifies the column name to join
# <br>
# The result it gives are the common values present in both CustomerId coulmns.
# <br>
# ## Combining 3 tables
# <br>
# consider table Shippers table also<br>
# <br>
#  <b>SELECT Orders.OrderID,Customers.CustomerName, Shippers.ShipperName</b>
# <br> <b>FROM (( Orders </b>            &nbsp;&nbsp;&nbsp;&nbsp;-- here at the position of taking a table only we have to complete one join
#     <br><b>   INNER JOIN Customer</b>         &nbsp;&nbsp;&nbsp;&nbsp;  -- here joining with one table
#       <br> <b>ON Orders.CustomerId=Customers.CustomerId)</b>      &nbsp;&nbsp;&nbsp;&nbsp;   -- here giving the column  and completing with first table
#        <br><b>INNER JOIN Shippers</b>          &nbsp;&nbsp;&nbsp;&nbsp; -- here with secound table
#        <br><b>ON Shippers.CustomerID=Customers.CustomerId)</b>     &nbsp;&nbsp;&nbsp;&nbsp;     -- join completed
#
# ##### LEFT JOIN
#  <b>SELECT Orders.OrderId, Customers.CustomerName</b> <br>
#  <b>FROM Orders </b>        &nbsp;&nbsp;&nbsp;&nbsp;  -- the table here becomes left or main<br>
#  <b>LEFT JOIN Customers</b>  &nbsp;&nbsp;&nbsp;&nbsp; -- this tells with witch table to join<br>
#  <b>ON Orders.CustomerID = Customers.CustomerID</b>    &nbsp;&nbsp;&nbsp;&nbsp;       -- this specifies the column name to join
# <br>
# here the total Order tables will get displayed and matching fields from Customers table<br>
# RIGHT JOIN is also same as like LEFT JOIN, here the main difference is wich tables comes as main it is left table.
# <br>
# ##### OUTER JOIN
#  <b>SELECT Orders.OrderId, Customers.CustomerName</b> <br>
#  <b>FROM Orders </b>        &nbsp;&nbsp;&nbsp;&nbsp;  -- the table here becomes left or main<br>
#  <b> FULL OUTER JOIN Customers</b>  &nbsp;&nbsp;&nbsp;&nbsp; -- this tells with witch table to join<br>
#  <b>ON Orders.CustomerID = Customers.CustomerID</b>    &nbsp;&nbsp;&nbsp;&nbsp;       -- this specifies the column name to join
# <br>
# here, total 2 tables will be combined with customerId as connection column, where, if it doesn not find any values, the field fills with NULL.

# %% [markdown]
# ## Aliasing
# this procedure is nothing but giving some rememberable names to the table. aliasing dont change the table names in database, but in the result and query it can be used for simplicity.
# <br>
# aliasing can be done to table names and column names also.
# ![alita.PNG](attachment:alita.PNG)

# %% [markdown]
# ![alicol.PNG](attachment:alicol.PNG)

# %% [markdown]
# also it can be done without AS, like<br>
# <b>FROM table_name alias_name<br>
# SELECT column_name alias_name</b>

# %% [markdown]
# ## DATA CALCULATIONS
# here, we are going to see some calculations used mostly in data analysis.
#
# <br>
# some common spreadsheet formulas are<br>
# <br>SUM
# COUNT<br>
# COUNTA<br>
# COUNTBLANK<br>
# AVERAGE<br>
# MIN Excel<br>
# MAX Excel<br>
# LEN Excel<br>
# TRIM Excel<br>
# IF Excel<br>
# <br>

# %% [markdown]
# ## SUMIF and SUMIFS
# The basic syntax of a SUMIF function is: =SUMIF(range, criterion, sum_range)<br>
# ![sumif.PNG](attachment:sumif.PNG)

# %% [markdown]
# ![sumifcon.PNG](attachment:sumifcon.PNG)

# %% [markdown]
# it counts the total price of fuel. sumif works as, it sums the corresponding range with respected to criterion range. to include more criterias, SUMIFS is used <br>
# <br>
# The basic syntax is:  =SUMIFS(sum_range, criteria_range1, criterion1, [criteria_range2, criterion2, ...])
# <br>
# ![sumifs.PNG](attachment:sumifs.PNG)

# %% [markdown]
# ## COUNTIF to COUNTIFS
# The basic syntax for COUNTIF is: =COUNTIF(range, criterion)<br>
# =COUNTIFS(criteria_range1, criterion1, [criteria_range2, criterion2, ...]) <br>
# ![countif.PNG](attachment:countif.PNG)

# %% [markdown]
# ![countifs.PNG](attachment:countifs.PNG)

# %% [markdown]
# ## AVERAGEIF
# The syntax is =AVERAGEIF(range, criteria, [sum_range]).
# ## SUMPRODUCT
# this function first multipies each field with its corresponding and than adds total of the result.
# Syntax =SUMPRODUCT(array1, [array2], [array3], ...)
# ![sumproduct.PNG](attachment:sumproduct.PNG)

# %% [markdown]
# ## Data Validation Process
# This process involves checking and rechecking the quality of your data so that it is complete, accurate, secure, and consistent.
# <br>
# 1) Data Type ->  Check that the data matches the data type defined for a field.
# 2) Data Range -> Check that the data falls within an acceptable range of values defined for the field.
# 3) Data Constrains -> Check that the data meets certain conditions or criteria for a field. This includes the type of data entered as well as other attributes of the field, such as number of characters.
# 4)  Data Consistency ->  Check that the data makes sense in the context of other related data.
# 5) Data Structure -> Check that the data follows or conforms to a set structure.
# 6) Code Validation -> Check that the application code systematically performs any of the previously mentioned validations during user data input.
#
# ## Temporary table
# Temporary tables, or temp tables, store subsets of data from standard data tables for a certain period of time.
# ![temptable.PNG](attachment:temptable.PNG)

# %% [markdown]
# ->They are automatically deleted from the database when you end your SQL session.
# <br>
# -> They can be used as a holding area for storing values if you are making a series of calculations. This is sometimes referred to as pre-processing of the data.
# <br>
# -> They can collect the results of multiple, separate queries. This is sometimes referred to as data staging. Staging is useful if you need to perform a query on the collected data or merge the collected data.
# <br>
# ->They can store a filtered subset of the database. You don’t need to select and filter the data each time you work with it. In addition, using fewer SQL commands helps to keep your data clean.

# %% [markdown]
# other than big query the syntax for temp table is
# ![into.PNG](attachment:into.PNG)
