# %% [markdown]
# ## Structured Thinking
#
# the process of recognising the current problem or situation, organise the available information, understand the gaps and identify the options.
# ## The six data analysis phases explained
#
# <br>
# ## Ask
# -> Define the problem <br>
# -> make sure you understand <br>
# -> focus on problem and avoid distractions <br>
# -> collaborate with stakeholders and keep an open line communication <br>
# -> keep a step back and see whole situation in context <br>
# ## Prepare
#
#
#  this is where, you think about collecting data <br>
#
# -> What metrics to measure<br>
#
# ->Locate data in your database<br>
#
# ->Create security measures to protect that data<br>
#
# ## Process
# here, you clean your data
#
# <br>
# ->sing spreadsheet functions to find incorrectly entered data <br>
#
# ->Using SQL functions to check for extra spaces <br>
#
# ->Removing repeated entries<br>
# ->Checking as much as possible for bias in the data<br>
#
# ## Analyze
#
# ->Perform calculations <br>
#
# ->Combine data from multiple sources <br>
#
# ->Create tables with your results<br>
#
# ## Share
# here, you visualize the data that you have been analysed.
#
# ->Make better decisions <br>
#
# ->Make more informed decisions <br>
#
# ->Lead to stronger outcomes<br>
#
# ->Successfully communicate your findings<br>
#
# ## Act
# which means, putting all the alanysis to gether, means providing stake holders with recommendations.
#
#
#
# ## problem types
#
# the data analysis job is all about problem solving skills to proceed. it is the daily part of the data analyst.  <br>
#
# here, we lets understand the six common problem types of data analysis.<br>
#
# 1) making predictions <br>
# 2) categorizing things <br>
# 3) spotting something unusual <br>
# 4) identifying themes <br>
# 5) discovering connectins <br>
# 6) finding patterns <br>
#
# ## making predictions
#
# this type, involves using data to make informed decision about how things may be in the future.
#  <br>
#     for example, consider a hospital giving vital to some patients. the patients takes pills every day in their houses. the information of taking pills is combined with other each individual factors like, age , condition, previous medical condition etc... with the information they got the hospital can analyse, what can be, any side effects or how will be the future health of the patients by the data.
#
# ## categorizing things
# this means, assigning information to different groups based on common feature. <br>
#
# example of these can be, an analysit can make the groups of most or least skill full in maintainence or repair or cleaning in a mechanic shop.
#
# ## spotting something unusual
#
# this means, the data which is different from normal data or pattern. <br>
#
# for example, a school had a sudden increase of 30% in the admissions this year than ususal. an analyst used this data to find the cause, that, there are some new buildings and ventures have been built last year in the region of the school.
#
# ## identify themes
# categorizing things involves assigning items to categories; identifying themes takes those categories a step further by grouping them into broader themes.
#
# ## discover connections
#
# this means understanding the issue and make groups accordingly,
#
# for example, a scooter company stopped its production because of not having tyres from tyre company. the tyre comapny has an issue with rubber company. the rubber comapany cant get the material enough to make strong rubber. so by collabarating and sharing data these three companies openly, can solve issues and more..
#
# ## finding patterns
#
# this includes by using the past data  recognising any patterns and finding the happening chances again.
#
# ## asking qeustions SMART way
#
# the one of the main points of being data analyst is to ask the right question. for that there are some paths can follow. <br>
#
# for example, if some one says this sandwich is good isnt it? this question has chance of explanation. <br>
# another one like, do you like growing here ? they can say yes or no . this also doesnt give you information. <br>
#
# for not to be trapped in this kind of questions, which seems legit but doesnt give the information we need and feels like worked out a lot. <br>
#
# the strategy asking qeustions is <br>
# S -> Specific <br>
# M -> Measurable <br>
# A -> Action-Oriented <br>
# R -> Relevant <br>
# T -> Time - Bound <br>
#
#
# ## Specific
#
# asking a focused question rather than general. <br>
#
# are the kids getting excerice these days ? is a too normal question, where we may or may not can explain. <br>
# asking like, the percentage of kids getting regular activities for an hour a day per 5 days a week. ? this gives details information of what we needed actually.
#
# overall, try to focus on a single aspect at a time, rather than normalizing the situation.
#
# ## Measurable
#
# measurable questions, that, those can be quantified. <br>
#
# it means having a number that can give the brief answer. <br>
#
# for example, asking how the video gone viral ? is too general.
# how many times the video is been shared in the first week ? will give measurement to understand the viral percentage.
#
# ## Action-Oriented
#
# these questions help to change the situation.  <br>
#
# like, asking for how to make our product recycle more ? <br> is normal
# asking what design can bring more recycle ? <br> making it action oriented. where, you can see a way to solve it.
#
# ## Relevant
#
# asking relevant question is really important to solve an issue. the question asked has to be very appropriate.
#
# for example, consider a situation that one kind of frog species are disappiaring and needed to ask a right and relevent question. <br>
#
# aksing like, how many are frog species are disappeared in an year ? can be not an accurate and irrilavent question. because, it is not focused on what happend and why. <br>
#
# asking like, what are the environmental factors that effect the corolina from 2000 to 2004 that caused the frog species disappear.? this gives a focused and relevant option and it makes the range of possibilities less.
# <br>
#
# in this  questioning we included a specific place and time so that finding makes easy rather than asking overall.
#
# ## time bound
#
# the qeustion has to be time bounded, so that, can focus on relevant data with less range of possibilities and accuracy.
#
#
# ## Data Inspired Decision making
#
# this is a data process to make decisions by comparing common things in it.
# <br>
# for example, consider the big loss of coke in 90s. when the pepsi started in competition to the coke, they [coke] had planned in launching a new kind of flavour and they tested over 200 000 000. members before launch and they got good results saying it is really nice flavour. than the company stopped the old flavour and released new one. but, unfortunatly the sales gone down and they lost millions of dollars. why because the data collected is not completed. they didnt included the question of asking how you compare it with the old flavour. this is called data driven decision on incompleted data.
# <br>
#
# even though, some times the data is complete, it needed to be collaborated. like, the space jet failure of NASA. tha data they have everything is perfect and they launched the rocket and its collapsed. after that an investigating team revealed the reason saying, it was the unit of measurement is different from one thruster to another. it measns one engine calculating force in newtons and another in pounds. even the data provided is correct but the application is gone wrong because of not havinng collaboration between the teams data, who developing these 2 thrusters. at this scenarios the data inspired decision making is the key to success.
#
#
# ## Data models
# -> Qualitative data <br>
# -> quantitative data <br>
#
# here, quantitative means, the data collected according to the facts, which means it has a direct number, and the qualitative data is where you analyse the reason of happening.<br>
#
# for example, an ice cream shop is having some declines in sales and they want to make use of data analysis. <br>
# they ask questions like<br>
#
# how many negetive reviews are there? <br>
# what is the average review ? <br>
# what is the common keyword in it ? <br>
#
# this questions brings the quantitative data, where it is measurable. <br>
# the questions like <br>
# why customers are not satified ?<br>
# how can we improve the customer satisfaction ? <br>
#
# these questions brings the qualitative data. which are reasons but not data according to the reasons. <br>
#  --> qualitative analysis can be done by focussed groups, social media, in person interviews.
#  --> quantitative analysis done by reviews, survey, polls.

# %% [markdown]
# ## data visualizing types
#
# -> report <br>
# -> dashboard <br>
#
# ## report
#
# report is used to show the historic data. it means, for example, to show a monthly sales or weekly sales of a company.
# reports are easy to use and nice snapshots for to show high level historical data. <br>
#
# reports use static data, and it reflects the data which is cleaned and sorted already. also reports needed to be maintained and these are not so visually appealing, because these are not automatic.
#
# ## dashboard
#
# dashboards used to visualize the live data, which is dynamic and dahsboards helps to interact with live data using filters. if a manager needed continues flow of data visualization, dashboards are more usefull than reports. it removes making over and over. because these are automated.
#
# <br>
#
# also dashboards takes so much time to build and not so efficient for small details. sashboards are not so much used in regular bases information. these are best used for presenting to the stakeholders.
#
# ## Metrics
#  a metrics is a single quantifiable type data that can be used for measurement. <br>
#  means, the data is  a collection of facts, where, metrics is organized individual data type. <br>
#
#  metrics can also be combined into formulas, where, you can plug your numerical data into. metrics usually involve simple maths. like calculating revenue can be  sales number multiplied by sales price.
#  <br>
#
#  for example, ROI. Return on Investment. these metric is used mostly with every company. ROI have net profit and cost of investment.
#
# ## The beauty of dashboards
# Dashboards are powerful visual tools that help you tell your data story. A dashboard
# organizes information from multiple datasets into one central location, offering huge timesavings. Data analysts use dashboards to track, analyze, and visualize data in order to
# answer questions and solve problems.
#
# <br>
#   Benifits :
#   <br>
#   Centralization: -> sharing single source of data with all stakeholders <br>
#   Visualization : -> showing and updating live incoming data.<br>
#   Insightfulness : -> Pulling relevant information
# from different datasets<br>
#   Customization  :->Creating custom views
# dedicated to a specific
# person, project, or
# presentation of the data<br>

# %% [markdown]
# ## Creating a dashboard
# 1. Identify the stakeholders who need to see the data and how they will use it <br>
# 2. Design the dashboard (what should be displayed) <br>
# 3. Create mock-ups if desired (its optional) <br>
# 4. Select the visualizations you will use on the dashboard <br>
# 5. Create filters as needed<br>

# %% [markdown]
# ## types of Dashboards
# Strategic: focuses on long term goals and strategies at the highest level of metrics <br>
# Operational: short-term performance tracking and intermediate goals<br>
# Analytical: consists of the datasets and the mathematics used in these sets<br>

# %% [markdown]
# ## strategic
#
# ![strgt.PNG](attachment:strgt.PNG)
# this overal dashboard concentrated on long term goals and results.

# %% [markdown]
# ## operational
# ![ope.PNG](attachment:ope.PNG)

# %% [markdown]
# in operational, it focused on a current specific problem of a comapany,where it involves only individual specific data.

# %% [markdown]
# ## Analytical
# ![anla.PNG](attachment:anla.PNG)

# %% [markdown]
# analytical dahsboards contains most of the information and these are the tough once. these kind of dashboards mostly used in between data team and rarely used for stakeholder submission.

# %% [markdown]
# ## Big and Small Data
#
# there, is a little differens in big and small data sets. its not the size of the dataset, it is how it is used.
#
# ![bsd.PNG](attachment:bsd.PNG)

# %% [markdown]
# ## The V's
# ![vs.PNG](attachment:vs.PNG)

# %% [markdown]
# it is simply said that the dataset consists of all the above vs. it is generally called as 3vs with extra veracity.

# %% [markdown]
# ## Spread Sheet and the Data Life Cycle
# ![lcdc.PNG](attachment:lcdc.PNG)

# %% [markdown]
# plan -> it means planning the spread sheet accordingly, on the base of whoes using it, hows the columns and rows etc...
# capture -> this phase means, connecting the spreadsheet with other resources to catch the updates as they change
# manage -> this involves storing, organizing, filtering etc..
# anlyzing -> involve data observation and making better decisions.
# archive -> the sheet that you dont use often but needed for the future reference can be archived.
# destroy -> when you done and never need it back.

# %% [markdown]
# ## spreadsheet formulas
#
#
# AVERAGE->
#   Statistical   Returns the numerical average value in a dataset, ignoring text.
# <br><br>
# AVERAGEIFS
# ->
# Statistical  Returns the average of a range that depends upon multiple criteria.
# <br><br>
# CHOOSE
# ->
# Lookup  Returns an element from a list of choices based on index.
# <br><br>
# COUNT
# ->
# Statistical  Returns the count of the number of numeric values in a dataset.
# <br><br>
# COUNTIF
# ->
# Statistical  Returns a conditional count across a range.
# <br><br>
# DATE
# ->
# Date  Converts a provided year, month, and day into a date.
# <br><br>
# FIND
# ->
# Text  Returns the position at which a string is first found within text.
# <br><br>
# GETPIVOTDATA
# ->
# Text  Extracts an aggregated value from a pivot table that corresponds to the specified row and column headings.
# <br><br>
# IF
# ->
# Logical  Returns one value if a logical expression is true and another if it is false.
# <br><br>
# INDEX
# ->
# Lookup  Returns the content of a cell, specified by row and column offset.
# <br><br>
# INT
# ->
# Math  Rounds a number down to the nearest integer that’s less than or equal to it.
# <br><br>
# LOOKUP
# ->
# Lookup  Looks through a row or column for a key and returns the value of the cell in a result range located in the same position as the search row or column.
# <br><br>
# MATCH
# ->
# Lookup  Returns the relative position of an item in a range that matches a specified value.
# <br><br>
# MAX
# ->
# Statistical  Returns the maximum value in a numeric dataset.
# <br><br>
# MIN
# ->
# Statistical  Returns the minimum value in a numeric dataset.
# <br><br>
# NOW
# ->
# Date  Returns the current date and time as a date value.
# <br><br>
# ROUND
# ->
# Math  Rounds a number to a certain number of decimal places according to standard rules.
# <br><br>
# SUM
# ->
# Math  Returns the sum of a series of numbers and/or cells.
# <br><br>
# SUMIF
# ->
# Math  Returns a conditional sum across a range.
# <br><br>
# TODAY
# ->
# Date  Returns the current date as a date value.
# <br><br>
# VLOOKUP
# ->
# Lookup  Searches down the first column of a range for a key and returns the value of a specified cell in the row found.<br>

# %% [markdown]
#  uses =(2+2) enter gives result in spreadsheet
